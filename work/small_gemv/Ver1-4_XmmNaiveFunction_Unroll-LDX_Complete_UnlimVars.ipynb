# %%
import re

def find_true_indices(lst, N):
    true_indices = [i for i, val in enumerate(lst) if val]
    return true_indices[:N]

def replace_multiple_newlines(text):
    # 3つ以上の連続する改行を2つの改行に置換
    return re.sub(r'\n{2,}', '\n\n', remove_spaces_from_blank_lines(text))

def remove_spaces_from_blank_lines(text):
    # 各行を処理し、スペースのみの行を空行に置き換える
    return re.sub(r'^\s+$', '', text, flags=re.MULTILINE)

def select_usable_xmm(usable_var):
    count_true = sum(usable_var)
    count_mod2 = (count_true>>1)<<1
    count_half = count_true>>1
    indices = find_true_indices(usable_var, count_mod2)
    
    vars1 = [f"xmm{idx}" for idx in indices[:count_half]]
    vars2 = [f"xmm{idx}" for idx in indices[count_half:]]
    for idx in indices:
        usable_var[idx] = False
    return vars1, vars2, usable_var 

def find_true_indices(lst, N):
    true_indices = [i for i, val in enumerate(lst) if val]
    return true_indices[:N]

def select_usable_var(usable_var, prefix="r", set_second=False):
    var1, var2 = "", ""
    indices = find_true_indices(usable_var, 2)
    
    var1 = f"{prefix}{indices[0]}"
    var2 = f"{prefix}{indices[1]}"
    usable_var[indices[0]] = False
    if set_second: usable_var[indices[1]] = False
    return var1, var2, usable_var

def accumulator_simd(accm_op, variables, indent_level=1):
    indent = " " * 4 * indent_level
    
    accm_op.append("\n")
    if len(variables) == 1:
        accm_op.append(variables[0])
        return 

    variables_next_ = []
    variables_ = variables[:-1] if len(variables) % 2 == 1 else variables
    for i in range(0, len(variables_), 2):
        accm_op.append(f"{indent}{variables_[i]} = _mm_add_pd({variables_[i]}, {variables_[i+1]});")
        variables_next_.append(f"{variables_[i]}")
        
    if len(variables) % 2 == 1:
        variables_next_.append(f"{variables[-1]}")
        
    accumulator_simd(accm_op, variables_next_, indent_level = indent_level)
    

def accumulator_naive_c(accm_op, variables, indent_level=1):
    indent = " " * 4 * indent_level
    
    accm_op.append("\n")
    if len(variables) == 1:
        accm_op.append(variables[0])
        return 

    variables_next_ = []
    variables_ = variables[:-1] if len(variables) % 2 == 1 else variables
    for i in range(0, len(variables_), 2):
        accm_op.append(f"{indent}{variables_[i]} = {variables_[i]} + {variables_[i+1]};")
        variables_next_.append(f"{variables_[i]}")
        
    if len(variables) % 2 == 1:
        variables_next_.append(f"{variables[-1]}")
        
    accumulator_naive_c(accm_op, variables_next_, indent_level = indent_level)    

with open(f"./small_dgemv_naive_c_implementation_ver1_4.c", "w") as p:
    p.write("#include <stddef.h>\n")
    p.write("#include <stdio.h>\n")
    p.write("#include <stdlib.h>\n")
    p.write("#include <stdint.h>\n")
    p.write("#include <math.h>\n")
    p.write("#include <omp.h>\n")
    p.write("#include <immintrin.h>\n") 
    p.write("""
double sum_xmm_elements_v1_4(__m128d xmmX) {
    __m128d xmm_high_low = _mm_add_pd(xmmX, _mm_unpackhi_pd(xmmX, xmmX));

    double result;
    _mm_store_sd(&result, xmm_high_low);

    return result;
}    
    """)

    for ldx in range(2, 514, 2):
#     for ldx in range(2, 512, 2):
        ldx_max = ldx
        declare_xmm = "__m128d " + ", ".join([f"xmm{ld}" for ld in range(ldx_max)])
        variables = [f"xmm{ld}" for ld in range(ldx_max)]

        usable_var = [True] * ldx_max
        
        vars1, vars2, usable_var = select_usable_xmm(usable_var)
    
        load_xmm = ""
        op_concat = ""

        for i, var in enumerate(vars2):
            load_xmm += f"""
        {var} = _mm_loadu_pd(&x[{i*2}]);"""
        
        if ldx<=1000:
            if ldx <=16:
                for i, var in enumerate(vars1):
                    op_concat += f"""
            {var} = _mm_loadu_pd(&a_t[{i*2}]);"""

                op_concat += "\n"
                for var1, var2 in zip(vars1, vars2):
                    op_concat += f"""
            {var1} = _mm_mul_pd({var1}, {var2});"""

                accm_variables = vars1
                accm_op = []
                accumulator_simd(accm_op, accm_variables, indent_level=2)
                op_concat += "\n".join(accm_op[:-1])

                op_concat += f"\n        y[i] = sum_xmm_elements_v1_4({accm_op[-1]}); a_t += {ldx};"

            else:
                for i, var in enumerate(vars1):
                    op_concat += f"""
            {var} = _mm_loadu_pd(&a_t[{i*2}]);"""
                    
                for var1, var2 in zip(vars1, vars2):
                    op_concat += f"""
            {var1} = _mm_mul_pd({var1}, {var2});"""

                accm_variables = vars1
                accm_op = []
                accumulator_naive_c(accm_op, accm_variables, indent_level=2)
                op_concat += "\n".join(accm_op[:-1])
                for var1, var2 in zip(vars1, vars2):
                    usable_var[int(var1[3:])] = True
                    usable_var[int(var2[3:])] = True
                usable_var[0] = False
                op_concat += f"\n        y[i] = sum_xmm_elements_v1_4({accm_op[-1]}); a_t += {ldx};"
            
        base = f"""
void mydgemv_t_ver1_4_{ldx}(double a_t[], double x[], double y[], int64_t lda, int64_t ldx, int64_t ldy){{
    {declare_xmm};
    {load_xmm}
    
    for (int i=0; i<lda; i++){{
        {op_concat}
        
    }}
}}
        """
        
        p.write(replace_multiple_newlines(base))
        
        
        ldx_max = ldx * 2 + 1
        declare_tmp_x = "double " + ", ".join([f"tmp_x_{ld} = x[{ld}]" for ld in range(ldx_max)])
        declare_xmm = "__m128d " + ", ".join([f"xmm{ld}" for ld in range(ldx_max)])
        variables = [f"xmm{ld}" for ld in range(ldx_max)]

        usable_var = [True] * ldx_max

        vars1, vars2, usable_var = select_usable_xmm(usable_var)

        load_a = ""
        load_xmm = ""
        comp_remain_ax = ""
        op_concat = ""

        # -------------------------------------------------------------------------------------------------
        # Load X
        for k, var in enumerate(vars2):
            load_xmm += f"""{var} = _mm_set1_pd(x[{k}]);
        """

        # Load A
        for k, var in enumerate(vars1):
            load_a += f"""{var} = _mm_loadu_pd(&a[i+{k}*lda]);
        """

        # multipy A x X
        mul_op = ""
        for var1, var2 in zip(vars1, vars2):
            mul_op += f"""{var1} = _mm_mul_pd({var2}, {var1});
        """
        # Accumulate AxX to y
        accm_variables = [f"xmm{ldx_max-1}"] + vars1
        accm_op = []
        accumulator_simd(accm_op, accm_variables, indent_level=2)
        accm_op = "\n".join(accm_op[:-1])

        # -------------------------------------------------------------------------------------------------        
        # Compute Remain 
        for k in range(ldx_max//2):
            comp_remain_ax += f"""tmp_a_{k} = a[i+{k}*lda] * x[{k}];
            """
        # Accumulate AxX to y
        accm_variables = [f"tmp_a_{k}" for k in range(ldx_max//2)] 
        accm_remain_op = []
        accumulator_naive_c(accm_remain_op, accm_variables, indent_level=2)
        accm_remain_op = "\n".join(accm_remain_op[1:-1])

        base = f"""
void mydgemv_n_ver1_4_{ldx}(double a[], double x[], double y[], int64_t lda, int64_t ldx, int64_t ldy){{
    {declare_xmm};
    {load_xmm}

    for (int64_t i=0; i<lda; i++){{
        y[i] = 0.0;
    }}

    int64_t i_remain = lda % 2;
    for (int64_t i=0; i<lda-i_remain; i+=2){{
        // Load y
        xmm{ldx_max-1} = _mm_loadu_pd(&y[i]);

        // Load a
        {load_a}

        // Multiply
        {mul_op}

        // Accumulate
        {accm_op}

        // Store y
        _mm_storeu_pd(&y[i], xmm{ldx_max-1});
    }}

    double tmp_y;
    double {", ".join([f"tmp_a_{i}" for i in range(ldx_max//2)])};
    for (int64_t i=lda-i_remain; i<lda; i++){{
        // Load y
        tmp_y = y[i];

        // Compute AxX
        {comp_remain_ax}

        // Accumulate AxX
{accm_remain_op}

        // Store y
        y[i] = tmp_a_0;
    }}
}}
            """
        p.write(replace_multiple_newlines(base))

# %%
for i in range(2, 514, 2):
#     print(f"""
#         subroutine mydgemv_t_ver1_4_{i}(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_t_ver1_4_{i}')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_t_ver1_4_{i}
#           """)

    print(f"""
        subroutine mydgemv_n_ver1_4_{i}(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_{i}')
            import
            integer(c_int64_t), value :: lda, ldx, ldy, shift
            real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
        end subroutine mydgemv_n_ver1_4_{i}
          """)
# Out:
#         subroutine mydgemv_n_ver1_4_2(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_2')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_2
#
#
#         subroutine mydgemv_n_ver1_4_4(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_4')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_4
#
#
#         subroutine mydgemv_n_ver1_4_6(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_6')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_6
#
#
#         subroutine mydgemv_n_ver1_4_8(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_8')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_8
#
#
#         subroutine mydgemv_n_ver1_4_10(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_10')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_10
#
#
#         subroutine mydgemv_n_ver1_4_12(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_12')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_12
#
#
#         subroutine mydgemv_n_ver1_4_14(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_14')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_14
#
#
#         subroutine mydgemv_n_ver1_4_16(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_16')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_16
#
#
#         subroutine mydgemv_n_ver1_4_18(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_18')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_18
#
#
#         subroutine mydgemv_n_ver1_4_20(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_20')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_20
#
#
#         subroutine mydgemv_n_ver1_4_22(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_22')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_22
#
#
#         subroutine mydgemv_n_ver1_4_24(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_24')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_24
#
#
#         subroutine mydgemv_n_ver1_4_26(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_26')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_26
#
#
#         subroutine mydgemv_n_ver1_4_28(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_28')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_28
#
#
#         subroutine mydgemv_n_ver1_4_30(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_30')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_30
#
#
#         subroutine mydgemv_n_ver1_4_32(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_32')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_32
#
#
#         subroutine mydgemv_n_ver1_4_34(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_34')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_34
#
#
#         subroutine mydgemv_n_ver1_4_36(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_36')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_36
#
#
#         subroutine mydgemv_n_ver1_4_38(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_38')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_38
#
#
#         subroutine mydgemv_n_ver1_4_40(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_40')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_40
#
#
#         subroutine mydgemv_n_ver1_4_42(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_42')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_42
#
#
#         subroutine mydgemv_n_ver1_4_44(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_44')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_44
#
#
#         subroutine mydgemv_n_ver1_4_46(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_46')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_46
#
#
#         subroutine mydgemv_n_ver1_4_48(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_48')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_48
#
#
#         subroutine mydgemv_n_ver1_4_50(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_50')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_50
#
#
#         subroutine mydgemv_n_ver1_4_52(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_52')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_52
#
#
#         subroutine mydgemv_n_ver1_4_54(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_54')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_54
#
#
#         subroutine mydgemv_n_ver1_4_56(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_56')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_56
#
#
#         subroutine mydgemv_n_ver1_4_58(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_58')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_58
#
#
#         subroutine mydgemv_n_ver1_4_60(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_60')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_60
#
#
#         subroutine mydgemv_n_ver1_4_62(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_62')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_62
#
#
#         subroutine mydgemv_n_ver1_4_64(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_64')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_64
#
#
#         subroutine mydgemv_n_ver1_4_66(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_66')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_66
#
#
#         subroutine mydgemv_n_ver1_4_68(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_68')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_68
#
#
#         subroutine mydgemv_n_ver1_4_70(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_70')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_70
#
#
#         subroutine mydgemv_n_ver1_4_72(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_72')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_72
#
#
#         subroutine mydgemv_n_ver1_4_74(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_74')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_74
#
#
#         subroutine mydgemv_n_ver1_4_76(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_76')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_76
#
#
#         subroutine mydgemv_n_ver1_4_78(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_78')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_78
#
#
#         subroutine mydgemv_n_ver1_4_80(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_80')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_80
#
#
#         subroutine mydgemv_n_ver1_4_82(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_82')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_82
#
#
#         subroutine mydgemv_n_ver1_4_84(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_84')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_84
#
#
#         subroutine mydgemv_n_ver1_4_86(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_86')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_86
#
#
#         subroutine mydgemv_n_ver1_4_88(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_88')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_88
#
#
#         subroutine mydgemv_n_ver1_4_90(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_90')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_90
#
#
#         subroutine mydgemv_n_ver1_4_92(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_92')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_92
#
#
#         subroutine mydgemv_n_ver1_4_94(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_94')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_94
#
#
#         subroutine mydgemv_n_ver1_4_96(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_96')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_96
#
#
#         subroutine mydgemv_n_ver1_4_98(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_98')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_98
#
#
#         subroutine mydgemv_n_ver1_4_100(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_100')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_100
#
#
#         subroutine mydgemv_n_ver1_4_102(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_102')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_102
#
#
#         subroutine mydgemv_n_ver1_4_104(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_104')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_104
#
#
#         subroutine mydgemv_n_ver1_4_106(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_106')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_106
#
#
#         subroutine mydgemv_n_ver1_4_108(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_108')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_108
#
#
#         subroutine mydgemv_n_ver1_4_110(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_110')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_110
#
#
#         subroutine mydgemv_n_ver1_4_112(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_112')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_112
#
#
#         subroutine mydgemv_n_ver1_4_114(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_114')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_114
#
#
#         subroutine mydgemv_n_ver1_4_116(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_116')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_116
#
#
#         subroutine mydgemv_n_ver1_4_118(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_118')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_118
#
#
#         subroutine mydgemv_n_ver1_4_120(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_120')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_120
#
#
#         subroutine mydgemv_n_ver1_4_122(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_122')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_122
#
#
#         subroutine mydgemv_n_ver1_4_124(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_124')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_124
#
#
#         subroutine mydgemv_n_ver1_4_126(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_126')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_126
#
#
#         subroutine mydgemv_n_ver1_4_128(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_128')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_128
#
#
#         subroutine mydgemv_n_ver1_4_130(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_130')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_130
#
#
#         subroutine mydgemv_n_ver1_4_132(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_132')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_132
#
#
#         subroutine mydgemv_n_ver1_4_134(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_134')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_134
#
#
#         subroutine mydgemv_n_ver1_4_136(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_136')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_136
#
#
#         subroutine mydgemv_n_ver1_4_138(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_138')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_138
#
#
#         subroutine mydgemv_n_ver1_4_140(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_140')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_140
#
#
#         subroutine mydgemv_n_ver1_4_142(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_142')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_142
#
#
#         subroutine mydgemv_n_ver1_4_144(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_144')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_144
#
#
#         subroutine mydgemv_n_ver1_4_146(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_146')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_146
#
#
#         subroutine mydgemv_n_ver1_4_148(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_148')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_148
#
#
#         subroutine mydgemv_n_ver1_4_150(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_150')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_150
#
#
#         subroutine mydgemv_n_ver1_4_152(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_152')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_152
#
#
#         subroutine mydgemv_n_ver1_4_154(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_154')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_154
#
#
#         subroutine mydgemv_n_ver1_4_156(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_156')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_156
#
#
#         subroutine mydgemv_n_ver1_4_158(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_158')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_158
#
#
#         subroutine mydgemv_n_ver1_4_160(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_160')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_160
#
#
#         subroutine mydgemv_n_ver1_4_162(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_162')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_162
#
#
#         subroutine mydgemv_n_ver1_4_164(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_164')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_164
#
#
#         subroutine mydgemv_n_ver1_4_166(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_166')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_166
#
#
#         subroutine mydgemv_n_ver1_4_168(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_168')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_168
#
#
#         subroutine mydgemv_n_ver1_4_170(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_170')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_170
#
#
#         subroutine mydgemv_n_ver1_4_172(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_172')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_172
#
#
#         subroutine mydgemv_n_ver1_4_174(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_174')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_174
#
#
#         subroutine mydgemv_n_ver1_4_176(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_176')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_176
#
#
#         subroutine mydgemv_n_ver1_4_178(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_178')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_178
#
#
#         subroutine mydgemv_n_ver1_4_180(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_180')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_180
#
#
#         subroutine mydgemv_n_ver1_4_182(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_182')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_182
#
#
#         subroutine mydgemv_n_ver1_4_184(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_184')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_184
#
#
#         subroutine mydgemv_n_ver1_4_186(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_186')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_186
#
#
#         subroutine mydgemv_n_ver1_4_188(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_188')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_188
#
#
#         subroutine mydgemv_n_ver1_4_190(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_190')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_190
#
#
#         subroutine mydgemv_n_ver1_4_192(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_192')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_192
#
#
#         subroutine mydgemv_n_ver1_4_194(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_194')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_194
#
#
#         subroutine mydgemv_n_ver1_4_196(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_196')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_196
#
#
#         subroutine mydgemv_n_ver1_4_198(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_198')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_198
#
#
#         subroutine mydgemv_n_ver1_4_200(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_200')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_200
#
#
#         subroutine mydgemv_n_ver1_4_202(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_202')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_202
#
#
#         subroutine mydgemv_n_ver1_4_204(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_204')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_204
#
#
#         subroutine mydgemv_n_ver1_4_206(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_206')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_206
#
#
#         subroutine mydgemv_n_ver1_4_208(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_208')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_208
#
#
#         subroutine mydgemv_n_ver1_4_210(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_210')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_210
#
#
#         subroutine mydgemv_n_ver1_4_212(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_212')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_212
#
#
#         subroutine mydgemv_n_ver1_4_214(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_214')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_214
#
#
#         subroutine mydgemv_n_ver1_4_216(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_216')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_216
#
#
#         subroutine mydgemv_n_ver1_4_218(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_218')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_218
#
#
#         subroutine mydgemv_n_ver1_4_220(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_220')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_220
#
#
#         subroutine mydgemv_n_ver1_4_222(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_222')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_222
#
#
#         subroutine mydgemv_n_ver1_4_224(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_224')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_224
#
#
#         subroutine mydgemv_n_ver1_4_226(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_226')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_226
#
#
#         subroutine mydgemv_n_ver1_4_228(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_228')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_228
#
#
#         subroutine mydgemv_n_ver1_4_230(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_230')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_230
#
#
#         subroutine mydgemv_n_ver1_4_232(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_232')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_232
#
#
#         subroutine mydgemv_n_ver1_4_234(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_234')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_234
#
#
#         subroutine mydgemv_n_ver1_4_236(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_236')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_236
#
#
#         subroutine mydgemv_n_ver1_4_238(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_238')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_238
#
#
#         subroutine mydgemv_n_ver1_4_240(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_240')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_240
#
#
#         subroutine mydgemv_n_ver1_4_242(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_242')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_242
#
#
#         subroutine mydgemv_n_ver1_4_244(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_244')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_244
#
#
#         subroutine mydgemv_n_ver1_4_246(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_246')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_246
#
#
#         subroutine mydgemv_n_ver1_4_248(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_248')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_248
#
#
#         subroutine mydgemv_n_ver1_4_250(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_250')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_250
#
#
#         subroutine mydgemv_n_ver1_4_252(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_252')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_252
#
#
#         subroutine mydgemv_n_ver1_4_254(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_254')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_254
#
#
#         subroutine mydgemv_n_ver1_4_256(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_256')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_256
#
#
#         subroutine mydgemv_n_ver1_4_258(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_258')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_258
#
#
#         subroutine mydgemv_n_ver1_4_260(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_260')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_260
#
#
#         subroutine mydgemv_n_ver1_4_262(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_262')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_262
#
#
#         subroutine mydgemv_n_ver1_4_264(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_264')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_264
#
#
#         subroutine mydgemv_n_ver1_4_266(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_266')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_266
#
#
#         subroutine mydgemv_n_ver1_4_268(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_268')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_268
#
#
#         subroutine mydgemv_n_ver1_4_270(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_270')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_270
#
#
#         subroutine mydgemv_n_ver1_4_272(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_272')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_272
#
#
#         subroutine mydgemv_n_ver1_4_274(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_274')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_274
#
#
#         subroutine mydgemv_n_ver1_4_276(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_276')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_276
#
#
#         subroutine mydgemv_n_ver1_4_278(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_278')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_278
#
#
#         subroutine mydgemv_n_ver1_4_280(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_280')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_280
#
#
#         subroutine mydgemv_n_ver1_4_282(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_282')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_282
#
#
#         subroutine mydgemv_n_ver1_4_284(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_284')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_284
#
#
#         subroutine mydgemv_n_ver1_4_286(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_286')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_286
#
#
#         subroutine mydgemv_n_ver1_4_288(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_288')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_288
#
#
#         subroutine mydgemv_n_ver1_4_290(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_290')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_290
#
#
#         subroutine mydgemv_n_ver1_4_292(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_292')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_292
#
#
#         subroutine mydgemv_n_ver1_4_294(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_294')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_294
#
#
#         subroutine mydgemv_n_ver1_4_296(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_296')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_296
#
#
#         subroutine mydgemv_n_ver1_4_298(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_298')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_298
#
#
#         subroutine mydgemv_n_ver1_4_300(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_300')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_300
#
#
#         subroutine mydgemv_n_ver1_4_302(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_302')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_302
# ...
#         end subroutine mydgemv_n_ver1_4_412
#
#
#         subroutine mydgemv_n_ver1_4_414(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_414')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_414
#
#
#         subroutine mydgemv_n_ver1_4_416(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_416')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_416
#
#
#         subroutine mydgemv_n_ver1_4_418(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_418')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_418
#
#
#         subroutine mydgemv_n_ver1_4_420(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_420')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_420
#
#
#         subroutine mydgemv_n_ver1_4_422(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_422')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_422
#
#
#         subroutine mydgemv_n_ver1_4_424(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_424')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_424
#
#
#         subroutine mydgemv_n_ver1_4_426(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_426')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_426
#
#
#         subroutine mydgemv_n_ver1_4_428(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_428')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_428
#
#
#         subroutine mydgemv_n_ver1_4_430(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_430')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_430
#
#
#         subroutine mydgemv_n_ver1_4_432(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_432')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_432
#
#
#         subroutine mydgemv_n_ver1_4_434(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_434')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_434
#
#
#         subroutine mydgemv_n_ver1_4_436(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_436')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_436
#
#
#         subroutine mydgemv_n_ver1_4_438(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_438')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_438
#
#
#         subroutine mydgemv_n_ver1_4_440(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_440')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_440
#
#
#         subroutine mydgemv_n_ver1_4_442(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_442')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_442
#
#
#         subroutine mydgemv_n_ver1_4_444(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_444')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_444
#
#
#         subroutine mydgemv_n_ver1_4_446(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_446')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_446
#
#
#         subroutine mydgemv_n_ver1_4_448(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_448')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_448
#
#
#         subroutine mydgemv_n_ver1_4_450(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_450')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_450
#
#
#         subroutine mydgemv_n_ver1_4_452(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_452')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_452
#
#
#         subroutine mydgemv_n_ver1_4_454(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_454')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_454
#
#
#         subroutine mydgemv_n_ver1_4_456(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_456')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_456
#
#
#         subroutine mydgemv_n_ver1_4_458(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_458')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_458
#
#
#         subroutine mydgemv_n_ver1_4_460(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_460')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_460
#
#
#         subroutine mydgemv_n_ver1_4_462(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_462')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_462
#
#
#         subroutine mydgemv_n_ver1_4_464(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_464')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_464
#
#
#         subroutine mydgemv_n_ver1_4_466(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_466')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_466
#
#
#         subroutine mydgemv_n_ver1_4_468(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_468')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_468
#
#
#         subroutine mydgemv_n_ver1_4_470(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_470')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_470
#
#
#         subroutine mydgemv_n_ver1_4_472(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_472')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_472
#
#
#         subroutine mydgemv_n_ver1_4_474(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_474')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_474
#
#
#         subroutine mydgemv_n_ver1_4_476(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_476')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_476
#
#
#         subroutine mydgemv_n_ver1_4_478(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_478')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_478
#
#
#         subroutine mydgemv_n_ver1_4_480(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_480')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_480
#
#
#         subroutine mydgemv_n_ver1_4_482(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_482')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_482
#
#
#         subroutine mydgemv_n_ver1_4_484(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_484')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_484
#
#
#         subroutine mydgemv_n_ver1_4_486(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_486')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_486
#
#
#         subroutine mydgemv_n_ver1_4_488(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_488')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_488
#
#
#         subroutine mydgemv_n_ver1_4_490(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_490')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_490
#
#
#         subroutine mydgemv_n_ver1_4_492(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_492')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_492
#
#
#         subroutine mydgemv_n_ver1_4_494(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_494')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_494
#
#
#         subroutine mydgemv_n_ver1_4_496(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_496')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_496
#
#
#         subroutine mydgemv_n_ver1_4_498(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_498')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_498
#
#
#         subroutine mydgemv_n_ver1_4_500(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_500')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_500
#
#
#         subroutine mydgemv_n_ver1_4_502(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_502')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_502
#
#
#         subroutine mydgemv_n_ver1_4_504(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_504')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_504
#
#
#         subroutine mydgemv_n_ver1_4_506(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_506')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_506
#
#
#         subroutine mydgemv_n_ver1_4_508(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_508')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_508
#
#
#         subroutine mydgemv_n_ver1_4_510(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_510')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_510
#
#
#         subroutine mydgemv_n_ver1_4_512(a_t, x, y, lda, ldx, ldy, shift) bind(C, name='mydgemv_n_ver1_4_512')
#             import
#             integer(c_int64_t), value :: lda, ldx, ldy, shift
#             real(c_double), intent(in) :: a_t(ldx, lda), x(ldx), y(ldy)
#         end subroutine mydgemv_n_ver1_4_512
